# %%
import tkinter as tk
from tkinter import messagebox
import matplotlib.pyplot as plt

def convert_and_plot():
    try:
        celsius = float(entry_celsius.get())
        fahrenheit = (celsius * 9/5) + 32
        
        # Update the result label
        label_result.config(text=f"{fahrenheit:.2f} °F")
        
# Plot the single data points with different colors
plt.figure(figsize=(6, 4))

# Celsius point in blue
plt.scatter(celsius, 0, color='blue', label=f'{celsius}°C', marker='o')

# Fahrenheit point in red
plt.scatter(0, fahrenheit, color='red', label=f'{fahrenheit:.2f}°F', marker='o')

plt.title("Celsius vs Fahrenheit Points")
plt.xlabel("Celsius (°C)")
plt.ylabel("Fahrenheit (°F)")
plt.axhline(0, color='gray', linestyle='--', linewidth=0.5)  # Horizontal line at y=0
plt.axvline(0, color='gray', linestyle='--', linewidth=0.5)  # Vertical line at x=0
plt.legend()
plt.grid(True)
plt.show()

    except ValueError:
        messagebox.showerror("Input Error", "Please enter a valid number.")

# Create the main tkinter window
root = tk.Tk()
root.title("Celsius to Fahrenheit Converter with Visualization")

# Label and entry for Celsius input
label_celsius = tk.Label(root, text="Enter Celsius:")  
label_celsius.grid(row=0, column=0, padx=10, pady=10)

entry_celsius = tk.Entry(root)
entry_celsius.grid(row=0, column=1, padx=10, pady=10)

# Button to trigger the conversion and visualization
button_convert = tk.Button(root, text="Convert and Plot", command=convert_and_plot)
button_convert.grid(row=1, column=0, columnspan=2, pady=10)

# Label to display the conversion result
label_result = tk.Label(root, text="Result will appear here")
label_result.grid(row=2, column=0, columnspan=2, pady=10)

# Run the tkinter event loop
root.mainloop()
# Out:
#   Cell In[12], line 14
#     plt.figure(figsize=(6, 4))
#                               ^
# SyntaxError: expected 'except' or 'finally' block

# %%
import tkinter as tk
import matplotlib.pyplot as plt

def convert_and_plot():
    celsius = float(entry_celsius.get())
    fahrenheit = (celsius * 9/5) + 32
        
    # Update the result label
    label_result.config(text=f"{fahrenheit:.2f} °F")
        
    # Plot the single data point on a graph
    plt.figure(figsize=(6, 4))
    plt.scatter(celsius, fahrenheit, color='red', label=f'{celsius}°C = {fahrenheit:.2f}°F')
    plt.title("Celsius to Fahrenheit Conversion")
    plt.xlabel("Celsius (°C)")
    plt.ylabel("Fahrenheit (°F)")
    plt.axhline(0, color='gray', linestyle='--', linewidth=0.5)  # Horizontal line at y=0
    plt.axvline(0, color='gray', linestyle='--', linewidth=0.5)  # Vertical line at x=0
    plt.legend()
    plt.grid(True)
    plt.show()

# Create the main tkinter window
root = tk.Tk()
root.title("Celsius to Fahrenheit Converter with Visualization")

# Label and entry for Celsius input
label_=celsius = tk.Label(root, text="Enter Celsius:")
label_celsius.grid(row=0, column=0, padx=10, pady=10)

entry_celsius = tk.Entry(root)
entry_celsius.grid(row=0, column=1, padx=10, pady=10)

# Button to trigger the conversion and visualization
button_convert = tk.Button(root, text="Convert and Plot", command=convert_and_plot)
button_convert.grid(row=1, column=0, columnspan=2, pady=10)

# Label to display the conversion result
label_result = tk.Label(root, text="Result will appear here")
label_result.grid(row=2, column=0, columnspan=2, pady=10)

# Run the tkinter event loop
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[10], line 29
#      27 # Label and entry for Celsius input
#      28 label_=celsius = tk.Label(root, text="Enter Celsius:")
# ---> 29 label_celsius.grid(row=0, column=0, padx=10, pady=10)
#      31 entry_celsius = tk.Entry(root)
#      32 entry_celsius.grid(row=0, column=1, padx=10, pady=10)
#
# File ~\anaconda3\Lib\tkinter\__init__.py:2580, in Grid.grid_configure(self, cnf, **kw)
#    2565 def grid_configure(self, cnf={}, **kw):
#    2566     """Position a widget in the parent widget in a grid. Use as options:
#    2567     column=number - use cell identified with given column (starting with 0)
#    2568     columnspan=number - this widget will span several columns
#    (...)
#    2578                   widget stick to the cell boundary
#    2579     """
# -> 2580     self.tk.call(
# ...

# %%
import tkinter as tk
from tkinter import messagebox
import matplotlib.pyplot as plt

def convert_and_plot():
    try:
        celsius = float(entry_celsius.get())  # Get Celsius value from input
        fahrenheit = (celsius * 9/5) + 32     # Convert to Fahrenheit
        
        # Update the result label with the Fahrenheit value
        label_result.config(text=f"{fahrenheit:.2f} °F")
        
        # Plot the single data points with different colors
        plt.figure(figsize=(6, 4))

        # Celsius point in blue
        plt.scatter(celsius, 0, color='blue', label=f'{celsius}°C', marker='o')

        # Fahrenheit point in red
        plt.scatter(0, fahrenheit, color='red', label=f'{fahrenheit:.2f}°F', marker='o')

        plt.title("Celsius vs Fahrenheit Points")
        plt.xlabel("Celsius (°C)")
        plt.ylabel("Fahrenheit (°F)")
        plt.axhline(0, color='gray', linestyle='--', linewidth=0.5)  # Horizontal line at y=0
        plt.axvline(0, color='gray', linestyle='--', linewidth=0.5)  # Vertical line at x=0
        plt.legend()
        plt.grid(True)
        plt.show()

    except ValueError:
        # Display error message if input is invalid
        messagebox.showerror("Input Error", "Please enter a valid number.")

# Create the main tkinter window
root = tk.Tk()
root.title("Celsius to Fahrenheit Converter with Visualization")

# Label and entry for Celsius input
label_celsius = tk.Label(root, text="Enter Celsius:")
label_celsius.grid(row=0, column=0, padx=10, pady=10)

entry_celsius = tk.Entry(root)
entry_celsius.grid(row=0, column=1, padx=10, pady=10)

# Button to trigger the conversion and visualization
button_convert = tk.Button(root, text="Convert and Plot", command=convert_and_plot)
button_convert.grid(row=1, column=0, columnspan=2, pady=10)

# Label to display the conversion result
label_result = tk.Label(root, text="Result will appear here")
label_result.grid(row=2, column=0, columnspan=2, pady=10)

# Run the tkinter event loop
root.mainloop()
